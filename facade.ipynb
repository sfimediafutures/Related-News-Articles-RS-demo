# %%
import pandas as pd
import pickle

# %%
class ArticleRecommendationFacade:
    def __init__(self, articles_path: str, recommendations_path: str):
        # Load articles data
        self.articles_df = pd.read_csv(articles_path)
        # Load recommendations data
        with open(recommendations_path, 'rb') as f:
            self.recommendations = pickle.load(f)
        
        # Optional caches for efficiency
        self.article_cache = {}
        self.recommendation_cache = {}
    
    def get_article(self, article_id: str) -> dict:
        """Retrieve article details by ID."""
        # Check cache first
        if article_id in self.article_cache:
            return self.article_cache[article_id]
        
        # Search for article in the DataFrame
        article_row = self.articles_df[self.articles_df['uuid'] == article_id]
        if not article_row.empty:
            article_data = article_row.iloc[0].to_dict()
            self.article_cache[article_id] = article_data  # Cache for future access
            return article_data
        else:
            return {}  # Return empty if not found
    
    def get_recommendations(self, article_id: str) -> list:
        """Retrieve recommendations for a given article ID."""
        # Check cache first
        if article_id in self.recommendation_cache:
            return self.recommendation_cache[article_id]
        
        # Find the recommendation dictionary for the article ID
        recommendation_dict = self._find_recommendation_dict(article_id)
        if recommendation_dict:
            recommended_articles = recommendation_dict.get('recommendations', [])
            self.recommendation_cache[article_id] = recommended_articles  # Cache
            return recommended_articles
        else:
            return []  # Return empty if no recommendations found

    def get_article_with_recommendations(self, article_id: str) -> dict:
        """Retrieve both article details and recommendations for the article ID."""
        article_data = self.get_article(article_id)
        recommendations = self.get_recommendations(article_id)
        
        # Combine data into a single dictionary
        return {
            "article": article_data,
            "recommendations": recommendations
        }
    
    def _find_recommendation_dict(self, article_id: str) -> dict:
        """Find the recommendation dictionary for a specific article ID."""
        for recommendation in self.recommendations:
            if recommendation.get('article id') == article_id:
                return recommendation
        return {}

# %%
# Initialize the facade with the provided paths
facade = ArticleRecommendationFacade('data/test_set_articles.csv', 'data/recommendations.pkl')

# Test example retrieval
sample_article_id = facade.articles_df['uuid'].iloc[0]  # Take the first article's ID
sample_result = facade.get_article_with_recommendations(sample_article_id)
sample_result
# Out:
# {'article': {'uuid': 'TV2-15394074',
#   'byline': "['Jack Theetha', 'Hege Skorpen Olsen', 'Sophie Amundsen Dregelid', 'Agnes Alstad Mogstad']",
#   'title': '– Hun er vår tids største kvinnesakskvinne',
#   'lead_text': 'GOD MORGEN NORGE (TV 2): Nå blir avdøde Shabana Rehman hyllet i minoritetsmiljøer.',
#   'creation_date': '2023-01-02 10:35:26+00:00',
#   'last_modified': '2023-01-02 23:26:33+00:00',
#   'tags': "['shabana rehman', 'mullaløft', 'bjørn egil halvorsen', 'shazia majid', 'mulla krekar', 'minoritetsjenter', 'kvinnekamp', 'innenriks', 'nyheter', 'god morgen norge']",
#   'url': 'https://www.tv2.no/nyheter/innenriks/hun-er-var-tids-storste-kvinnesakskvinne/15394074/',
#    '2022-05-10 10:34:42+00:00',
#    "Main article discusses Shabana Rehman's impact on women's rights and cultural boundaries. Potential article focuses on Eldan's experiences with cultural identity and bullying. Both address cultural challenges but differ in context and focus, hence a moderate score."),
#   (6,
#    'TV2-15394074',
#    'TV2-14523393',
#    0.6749829,
#    '2022-01-26 14:00:33+00:00',
#    "Main article focuses on Shabana Rehman's legacy and activism, while the potential article discusses her recent experience on a reality show. Both articles feature Rehman, but the connection to her broader impact is less direct in the second article."),
#   (6,
#    'TV2-15394074',
#    'TV2-14514600',
#    0.65604854,
#    '2022-01-23 09:45:12+00:00',
#    "Main article discusses Shabana Rehman's legacy and activism, while the potential article focuses on her experience in a reality show. Both articles feature Rehman, but the connection is more about her public persona than her activism."),
#   (6,
#    'TV2-15394074',
#    'TV2-14507104',
#    0.66083026,
#    '2022-01-20 09:24:24+00:00',
#    "Main article discusses Shabana Rehman's impact on women's rights and activism. Potential article focuses on Myra's struggles as a refugee and her rise in music. Both highlight personal journeys overcoming societal challenges, but differ in context and medium."),
#   (6,
#    'TV2-15394074',
#    'TV2-14504574',
#    0.6677958,
#    '2022-01-19 11:27:53+00:00',
#    "Main article discusses Shabana Rehman's legacy and activism, while the potential article focuses on her recent participation in 'Farmen kjendis'. Both articles feature Rehman, but the second article lacks depth on her impact and activism."),
#   (6,
#    'TV2-15394074',
#    'TV2-14488370',
#    0.6670159,
#    '2022-01-12 16:20:24+00:00',
#    "Main article focuses on Shabana Rehman's legacy and activism, while the potential article discusses a conflict involving her on a reality show. Both articles feature Rehman, but the connection is more about her experience in a specific context rather than her broader impact."),
#   (6,
#    'TV2-15394074',
#    'TV2-14473713',
#    0.68470293,
#    '2022-01-06 09:55:56+00:00',
#    "Main article discusses Shabana Rehman's impact on society and her activism. Potential article features Kjersti Grini's controversial comment and subsequent reflection on language and race, which ties into societal discussions on identity and respect, echoing themes from Rehman's legacy."),
#   (4,
#    'TV2-15394074',
#    'TV2-15212890',
#    0.74083114,
#    '2022-10-24 11:36:53+00:00',
#    "Main article discusses Shabana Rehman's impact on women's rights and activism in Norway. Potential article focuses on Taliban women and their roles in a patriarchal society. Both address women's issues but in vastly different contexts, leading to a low relatedness score."),
#   (4,
#    'TV2-15394074',
#    'TV2-15187080',
#    0.693842,
#    '2022-10-14 08:15:17+00:00',
#    "Main article discusses Shabana Rehman's activism and impact on women's rights, while the potential article focuses on Celine Smitt's experience with bullying and PTSD. Both address social issues but differ in context and subject matter, leading to a low relatedness score."),
#   (4,
#    'TV2-15394074',
#    'TV2-15182314',
#    0.68929464,
#    '2022-10-12 12:41:26+00:00',
#    "Main article discusses Shabana Rehman's impact on women's rights and activism. Potential article critiques media coverage of protests in Iran, highlighting issues of representation and activism. Both articles touch on activism but focus on different contexts and individuals."),
#   (4,
#    'TV2-15394074',
#    'TV2-15163709',
#    0.68985647,
#    '2022-10-05 15:52:42+00:00',
#    "Main article discusses Shabana Rehman's activism and impact on women's rights. Potential article focuses on a journalist's exploration of women in IS, highlighting different aspects of women's struggles. While both address women's issues, the contexts and themes differ significantly."),
#   (4,
#    'TV2-15394074',
#    'TV2-14504284',
#    0.66547215,
#    '2022-01-19 10:37:42+00:00',
#    "Main article discusses Shabana Rehman's impact on women's rights and societal norms. Potential article focuses on Emma Ellingsen's journey and her efforts to reduce prejudice. Both address social issues but differ in context and focus, leading to a moderate score."),
#   (3,
#    'TV2-15394074',
#    'TV2-15236510',
#    0.6873645,
#    '2022-11-02 14:11:29+00:00',
#    "Main article discusses Shabana Rehman's activism and impact on women's rights. Potential article focuses on Phaedra Al-Majid's whistleblowing on corruption in sports. Both involve strong women challenging societal norms, but their contexts and issues differ significantly."),
#   (3,
#    'TV2-15394074',
#    'TV2-15199411',
#    0.6639732,
#    '2022-10-19 11:26:25+00:00',
#    "Main article discusses Shabana Rehman's legacy as a women's rights activist. Potential article focuses on the tragic murder of Sunniva Borgen, highlighting violence against women. While both involve women's issues, the contexts and themes differ significantly."),
#   (3,
#    'TV2-15394074',
#    'TV2-14498293',
#    0.66142607,
#    '2022-01-17 09:27:54+00:00',
#    "Main article focuses on Shabana Rehman's legacy and activism, while the potential article discusses personal experiences related to a different public figure, Vebjørn Selbekk. The themes of public perception and personal struggle are present, but the connection is weak."),
#   (2,
#    'TV2-15394074',
#    'TV2-15123252',
#    0.6637734,
#    '2022-09-20 22:06:53+00:00',
#    "Main article discusses Shabana Rehman's impact on women's rights and activism. Potential article focuses on a reality TV show participant's personal fears and experiences. The topics are unrelated, with no thematic or contextual overlap."),
#   (2,
#    'TV2-15394074',
#    'TV2-14668090',
#    0.67535925,
#    '2022-03-24 10:00:36+00:00',
#    "Main article focuses on Shabana Rehman's legacy in women's rights and activism. Potential article discusses a reality show and a minister's participation, lacking thematic connection to Rehman's impact on society or women's issues.")],
#  'recommendations': ['TV2-15237542',
#   'TV2-15186618',
#   'TV2-14485687',
#   'TV2-14782225',
#   'TV2-14523393'],
#  'ground truth': ['TV2-14136242'],
#  'article id': 'TV2-15394074',
#  'Recall@5': np.float64(0.0),
#  'Precision@5': np.float64(0.0),
#  'MAP@5': 0}

# %%
facade.articles_df[facade.articles_df['uuid'] == 'TV2-15237542']
# Out:
# Empty DataFrame
# Columns: [uuid, byline, title, lead_text, creation_date, last_modified, tags, url, body_text, related_articles, section, related_media_links, related_articles_counts, cleaned_related_articles, creation_time, number_cleaned_related_articles, all_text, full_text_embeddings]
# Index: []

# %%
import pandas as pd
import pickle

# Load articles data
articles_df = pd.read_csv('data/test_set_articles.csv')

# Load recommendations data
with open('data/recommendations.pkl', 'rb') as f:
    recommendations = pickle.load(f)

# Convert the list of recommendation dictionaries into a DataFrame
recommendations_df = pd.DataFrame(recommendations)

# Rename 'article id' column to 'uuid' to match the articles DataFrame
recommendations_df.rename(columns={'article id': 'uuid'}, inplace=True)

# Merge the two DataFrames on 'uuid'
combined_df = pd.merge(articles_df, recommendations_df, on='uuid', how='left')

# Save the combined DataFrame to a new CSV file
combined_df.to_csv('data/combined_articles_recommendations.csv', index=False)
